# %% [markdown]
# # 02 - Transform Silver
# Clean and standardize Bronze Citi Bike data.

# %%
from src.jobs.transform_silver import write_silver
write_silver()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/06/27 07:26:00 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 2026-06-27 07:26:01,341 INFO Reading Bronze Delta table from s3a://lakehouse/bronze/citibike
# 26/06/27 07:26:02 WARN MetricsConfig: Cannot locate configuration: tried hadoop-metrics2-s3a-file-system.properties,hadoop-metrics2.properties
# 26/06/27 07:26:06 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# 2026-06-27 07:26:11,279 INFO Data quality summary after Silver cleaning
# 2026-06-27 07:26:12,496 INFO Writing Silver Delta table to s3a://lakehouse/silver/citibike
# +----+-----------------+------------+---------------+-------------+----------------------+
# ...
