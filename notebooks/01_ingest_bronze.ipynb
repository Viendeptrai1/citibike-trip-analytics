# %% [markdown]
# # 01 - Ingest Bronze
# Run the same reusable Bronze job used by the CLI pipeline.

# %%
from src.jobs.ingest_bronze import ingest_bronze
ingest_bronze()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/06/27 07:25:28 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 2026-06-27 07:25:29,400 INFO Reading raw Citi Bike CSV files from s3a://lakehouse/raw/citibike
# 26/06/27 07:25:30 WARN MetricsConfig: Cannot locate configuration: tried hadoop-metrics2-s3a-file-system.properties,hadoop-metrics2.properties
# 2026-06-27 07:25:34,733 INFO Writing Bronze Delta table to s3a://lakehouse/bronze/citibike
# 26/06/27 07:25:36 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# 2026-06-27 07:25:43,601 INFO Bronze rows written: 4

# %%
print("Hello")
# Out:
# Hello
