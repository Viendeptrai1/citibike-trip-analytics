# %% [markdown]
# # 03 - Build Gold
# Aggregate Silver records into analytics-ready Delta tables.

# %%
from src.jobs.build_gold import build_gold
build_gold()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/06/27 07:27:50 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 2026-06-27 07:27:51,420 INFO Reading Silver Delta table from s3a://lakehouse/silver/citibike
# 26/06/27 07:27:52 WARN MetricsConfig: Cannot locate configuration: tried hadoop-metrics2-s3a-file-system.properties,hadoop-metrics2.properties
# 26/06/27 07:27:57 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# 2026-06-27 07:28:06,377 INFO Writing gold_daily_rides to s3a://lakehouse/gold/citibike/gold_daily_rides
# 2026-06-27 07:28:11,659 INFO gold_daily_rides rows: 4
# 2026-06-27 07:28:12,339 INFO Writing gold_hourly_demand to s3a://lakehouse/gold/citibike/gold_hourly_demand
# 2026-06-27 07:28:17,221 INFO gold_hourly_demand rows: 4
# 2026-06-27 07:28:18,395 INFO Writing gold_top_start_stations to s3a://lakehouse/gold/citibike/gold_top_start_stations
# 2026-06-27 07:28:22,291 INFO gold_top_start_stations rows: 4
# 2026-06-27 07:28:22,852 INFO Writing gold_top_end_stations to s3a://lakehouse/gold/citibike/gold_top_end_stations
# 2026-06-27 07:28:26,209 INFO gold_top_end_stations rows: 4
# 2026-06-27 07:28:26,721 INFO Writing gold_user_type_behavior to s3a://lakehouse/gold/citibike/gold_user_type_behavior
# 2026-06-27 07:28:32,488 INFO gold_user_type_behavior rows: 2
# 2026-06-27 07:28:33,114 INFO Writing gold_bike_type_usage to s3a://lakehouse/gold/citibike/gold_bike_type_usage
# 2026-06-27 07:28:37,325 INFO gold_bike_type_usage rows: 2
# 2026-06-27 07:28:38,250 INFO Writing gold_station_od_pairs to s3a://lakehouse/gold/citibike/gold_station_od_pairs
# 2026-06-27 07:28:42,331 INFO gold_station_od_pairs rows: 4
